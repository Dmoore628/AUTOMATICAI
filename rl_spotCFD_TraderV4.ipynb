# %% [markdown]
# <a href="https://colab.research.google.com/github/Dmoore628/AUTOMATICAI/blob/main/rl_spotCFD_TraderV4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Cell 1
# ##Install Dependencies

# %%
# Install required packages
# !pip install --upgrade pip
# !pip install torch==2.0.1 torchvision
# !pip install numpy==1.23.5 pandas==1.5.3 matplotlib==3.7.1
# !pip install SQLAlchemy==2.0.19
# !pip install tqdm==4.66.1
# !pip install stable-baselines3[extra]==1.6.2
# !pip install tensorboard==2.9.1
# !pip install gym==0.21.0
# !pip install cloudpickle==1.4.1
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.3.1)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (3.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (0.44.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1) (3.30.5)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1) (18.1.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.16.0)
# Requirement already satisfied: SQLAlchemy==2.0.19 in /usr/local/lib/python3.10/dist-packages (2.0.19)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy==2.0.19) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy==2.0.19) (3.1.1)
# Requirement already satisfied: tqdm==4.66.1 in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Collecting stable-baselines3==1.6.2 (from stable-baselines3[extra]==1.6.2)
#   Using cached stable_baselines3-1.6.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting gym==0.21 (from stable-baselines3==1.6.2->stable-baselines3[extra]==1.6.2)
#   Using cached gym-0.21.0.tar.gz (1.5 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: tensorboard==2.9.1 in /usr/local/lib/python3.10/dist-packages (2.9.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (1.67.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (1.23.5)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (3.19.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (2.32.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.9.1) (0.44.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.9.1) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.9.1) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.9.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.9.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.9.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.9.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.9.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.9.1) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard==2.9.1) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.9.1) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.9.1) (3.2.2)
# Collecting gym==0.21.0
#   Using cached gym-0.21.0.tar.gz (1.5 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: cloudpickle==1.4.1 in /usr/local/lib/python3.10/dist-packages (1.4.1)

# %% [markdown]
# #Cell 2
# ##Import Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
from datetime import datetime, timedelta
import torch
import random
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
from tensorboard import notebook
from IPython.display import clear_output
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bffc234568aa> in <cell line: 11>()
#       9 import gym
#      10 from gym import spaces
# ---> 11 from stable_baselines3 import PPO
#      12 from stable_baselines3.common.vec_env import DummyVecEnv
#      13 from stable_baselines3.common.monitor import Monitor
#
# ModuleNotFoundError: No module named 'stable_baselines3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# #Cell 3

# %%
# Connect to the SQLite database
conn = sqlite3.connect('/content/Historical_tick_price_data.db')
# Load data into a DataFrame
query = "SELECT PRICE, DATETIME FROM trades"
data = pd.read_sql_query(query, conn)
conn.close()

# Parse DATETIME column
data['DATETIME'] = pd.to_datetime(data['DATETIME'], format='%Y-%m-%d %H:%M:%S')

# Remove weekend data (Forex market is closed on weekends)
data = data[(data['DATETIME'].dt.weekday >= 0) & (data['DATETIME'].dt.weekday <= 4)]

# Reset index after filtering
data = data.reset_index(drop=True)

# Calculate indicators
data['SMA_5'] = data['PRICE'].rolling(window=5).mean()
data['SMA_13'] = data['PRICE'].rolling(window=13).mean()
data['SMA_21'] = data['PRICE'].rolling(window=21).mean()

# MACD
ema_12 = data['PRICE'].ewm(span=12, adjust=False).mean()
ema_26 = data['PRICE'].ewm(span=26, adjust=False).mean()
data['MACD'] = ema_12 - ema_26
data['MACD_Signal'] = data['MACD'].ewm(span=9, adjust=False).mean()

# Bollinger Bands
data['BB_Middle'] = data['PRICE'].rolling(window=20).mean()
data['BB_Std'] = data['PRICE'].rolling(window=20).std()
data['BB_Upper'] = data['BB_Middle'] + (data['BB_Std'] * 2)
data['BB_Lower'] = data['BB_Middle'] - (data['BB_Std'] * 2)

# Fill NaN values resulting from rolling calculations
data.fillna(method='bfill', inplace=True)

# Normalize input features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features = ['PRICE', 'SMA_5', 'SMA_13', 'SMA_21', 'MACD', 'MACD_Signal', 'BB_Middle', 'BB_Upper', 'BB_Lower']
data[features] = scaler.fit_transform(data[features])

print(f"Total data points after preprocessing: {len(data)}")

# %% [markdown]
# #Cell 4

# %%
class TradingEnvironment(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, data, initial_balance=500, profit_target=25000, leverage=100, spread=0.0002, commission=0.0001):
        super(TradingEnvironment, self).__init__()

        self.data = data.reset_index(drop=True)
        self.initial_balance = initial_balance
        self.profit_target = profit_target
        self.leverage = leverage
        self.spread = spread
        self.commission = commission
        self.max_steps = len(self.data) - 1

        # Action space: Continuous action for position size adjustment between -1 and 1
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)

        # Observation space
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(12,), dtype=np.float32)

        # Initialize variables
        self.reset()

    def reset(self, start_idx=None):
        if start_idx is None:
            self.current_step = random.randint(0, self.max_steps - 1440 * 7)  # Ensure at least 7 days of data
        else:
            self.current_step = start_idx
        self.balance = self.initial_balance
        self.equity = self.initial_balance
        self.net_worth = self.initial_balance
        self.position_size = 0
        self.position_price = 0
        self.position_type = 0  # 1 for long, -1 for short, 0 for flat
        self.trade_history = []
        self.done = False
        self.start_time = self.data.loc[self.current_step, 'DATETIME']
        self.end_time = self.start_time + timedelta(days=7)
        self.highest_equity = self.initial_balance
        self.total_reward = 0
        self.episode_start_step = self.current_step
        return self._next_observation()

    def _next_observation(self):
        current_row = self.data.loc[self.current_step]
        obs = np.array([
            current_row['PRICE'],
            self.balance / self.initial_balance,
            (self.equity - self.initial_balance) / self.initial_balance,
            self.position_type,
            current_row['SMA_5'],
            current_row['SMA_13'],
            current_row['SMA_21'],
            current_row['MACD'],
            current_row['MACD_Signal'],
            current_row['BB_Middle'],
            current_row['BB_Upper'],
            current_row['BB_Lower']
        ], dtype=np.float32)
        return obs

    def step(self, action):
        action = action[0]  # Extract the action value
        current_price = self.data.loc[self.current_step, 'PRICE']
        time = self.data.loc[self.current_step, 'DATETIME']

        # Apply spread
        bid_price = current_price - self.spread
        ask_price = current_price + self.spread

        # Update position
        previous_position_size = self.position_size
        previous_position_type = self.position_type
        self._execute_trade(action, current_price, bid_price, ask_price)

        # Update equity
        self.equity = self.balance + self._get_unrealized_pnl(current_price)

        # Update highest equity for drawdown calculation
        if self.equity > self.highest_equity:
            self.highest_equity = self.equity

        # Calculate reward
        reward = self._calculate_reward(previous_position_size, previous_position_type, current_price)
        self.total_reward += reward

        # Check for termination conditions
        self.done = False
        if self.equity <= 0:
            self.done = True
            reward -= 50  # Severe penalty for bankruptcy
        elif self.equity >= self.profit_target:
            self.done = True
            reward += 100  # Large reward for hitting profit target
        elif time >= self.end_time:
            self.done = True
            if self.equity >= self.initial_balance:
                reward += 10  # Reward for surviving the week without bankruptcy

        # Move to the next step
        self.current_step += 1
        if self.current_step >= self.max_steps:
            self.done = True

        obs = self._next_observation()
        info = {}
        return obs, reward, self.done, info

    def _execute_trade(self, action, current_price, bid_price, ask_price):
        # Action represents the desired change in position size between -1 and 1
        max_position_size = self.equity * self.leverage  # Use equity for compounding
        desired_position_size = action * max_position_size
        position_change = desired_position_size - self.position_size

        if position_change > 0:
            # Increase long position or decrease short position
            trade_price = ask_price
            trade_type = 1  # Long
        elif position_change < 0:
            # Increase short position or decrease long position
            trade_price = bid_price
            trade_type = -1  # Short
        else:
            return  # Hold

        # Calculate required margin and fees
        required_margin = abs(position_change) / self.leverage
        fee = self.commission * abs(position_change)
        total_cost = required_margin + fee

        if self.balance >= total_cost:
            # Update balance and position
            self.balance -= total_cost
            self.position_size += position_change
            self.position_price = trade_price
            self.position_type = np.sign(self.position_size)
            self.trade_history.append({
                'step': self.current_step,
                'type': 'buy' if trade_type == 1 else 'sell',
                'price': trade_price,
                'size': position_change
            })
        else:
            pass  # Not enough balance to execute trade

    def _get_unrealized_pnl(self, current_price):
        if self.position_size == 0:
            return 0
        else:
            price_diff = (current_price - self.position_price) * self.position_type
            return price_diff * abs(self.position_size)

    def _calculate_reward(self, previous_position_size, previous_position_type, current_price):
        # Immediate profit incentive
        profit = self.equity - self.initial_balance
        profit_reward = profit / self.initial_balance

        # Compounding incentive
        compounding_reward = (self.equity / self.initial_balance) ** 2

        # Penalty for unrealized losses
        unrealized_pnl = self._get_unrealized_pnl(current_price)
        if unrealized_pnl < 0:
            unrealized_loss_penalty = 2 * (abs(unrealized_pnl) / self.initial_balance)
        else:
            unrealized_loss_penalty = 0

        # Penalty for turning significant profit into loss
        if previous_position_size != 0 and unrealized_pnl < 0 and profit > 0:
            profit_to_loss_penalty = abs(unrealized_pnl) / self.initial_balance
        else:
            profit_to_loss_penalty = 0

        # Tiered drawdown penalty
        drawdown = (self.highest_equity - self.equity) / self.highest_equity
        if drawdown > 0.2:
            drawdown_penalty = 5 * drawdown
        elif drawdown > 0.1:
            drawdown_penalty = 2 * drawdown
        else:
            drawdown_penalty = drawdown

        # Total reward
        reward = profit_reward + compounding_reward - unrealized_loss_penalty - profit_to_loss_penalty - drawdown_penalty
        return reward

    def render(self, mode='human'):
        # Visualization code will be added in the training loop
        pass

# %% [markdown]
# #Cell 5

# %%
# Create the environment
env = TradingEnvironment(data)

# Wrap the environment
env = Monitor(env)
env = DummyVecEnv([lambda: env])

# %% [markdown]
# #Cell 6

# %%
from stable_baselines3.common.callbacks import BaseCallback

class VisualizationCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(VisualizationCallback, self).__init__(verbose)
        self.episode = 0

    def _on_step(self) -> bool:
        return True

    def _on_rollout_end(self):
        # Access the environment
        env = self.training_env.envs[0].envs[0]

        # Plot the episode
        self.plot_episode(env)
        self.episode += 1

    def plot_episode(self, env):
        plt.figure(figsize=(12, 6))
        start = env.episode_start_step
        end = env.current_step
        price = env.data['PRICE'].iloc[start:end].reset_index(drop=True)
        plt.plot(price, label='Price')

        # Plot trades
        for trade in env.trade_history:
            step = trade['step'] - start
            if trade['type'] == 'buy':
                plt.plot(step, price.iloc[step], 'g^', label='Buy' if 'Buy' not in plt.gca().get_legend_handles_labels()[1] else "")
            else:
                plt.plot(step, price.iloc[step], 'rv', label='Sell' if 'Sell' not in plt.gca().get_legend_handles_labels()[1] else "")

        plt.title(f'Episode {self.episode}')
        plt.xlabel('Time Steps')
        plt.ylabel('Normalized Price')
        plt.legend()
        plt.show()
        plt.close()

# Define the checkpoint callback
checkpoint_callback = CheckpointCallback(save_freq=10000, save_path='/content/checkpoints/', name_prefix='ppo_trading_model')

# %% [markdown]
# #Cell 7

# %%
# Initialize the agent
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log="/content/logs")

# Set up the visualization callback
visualization_callback = VisualizationCallback()

# Start training with checkpointing and visualization
model.learn(total_timesteps=100000, callback=[checkpoint_callback, visualization_callback])

# %% [markdown]
# #Cell 8

# %%
# Start TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir /content/logs

# %% [markdown]
# #Cell 9

# %%
model.save('ppo_trading_agent')
print("Model saved successfully.")

# %% [markdown]
# #Cell 10

# %%
# Load the latest checkpoint
latest_checkpoint = '/content/checkpoints/ppo_trading_model_100000_steps.zip'  # Replace with your latest checkpoint file
model = PPO.load(latest_checkpoint, env=env)

# Continue training
model.learn(total_timesteps=100000, callback=[checkpoint_callback, visualization_callback])

# %% [markdown]
# #Cell 11

# %% [markdown]
# #Cell 12

# %% [markdown]
# #Cell 13

# %% [markdown]
# # Bankruptcy Rate and Success Rate Calculation
#
# **Bankruptcy Rate:**
#
# - **Definition:** The proportion of episodes where the agent's equity or balance falls to zero or below, resulting in bankruptcy.
# - **Calculation in Parallel Processing:**
#   - Each environment in the vectorized environments runs an episode independently.
#   - When an episode ends due to bankruptcy in any environment, it increments the bankruptcy count.
#   - **Bankruptcy Rate = Total Bankruptcy Episodes / Total Episodes Completed**
#
# **Success Rate:**
#
# - **Definition:** The proportion of episodes where the agent's equity reaches or exceeds the profit target (\$25,000) within the 7-day period.
# - **Calculation in Parallel Processing:**
#   - Similar to bankruptcy rate, success is tracked individually in each environment.
#   - When an episode ends with the agent reaching the profit target, it increments the success count.
#   - **Success Rate = Total Successful Episodes / Total Episodes Completed**
#
# **Notes:**
#
# - **Total Episodes Completed** includes all episodes across all environments.
# - Since episodes are running in parallel, counts are aggregated across all environments.
# - **Careful synchronization** is required to ensure counts are accurate.
#
# **Ensuring Correctness:**
#
# - Tianshou's built-in metrics tracking ensures that counts are correctly aggregated.
# - Custom callbacks can be used to track and log these metrics accurately.

# %%
import pandas as pd
import time
import sqlite3

# Connect to the database
conn = sqlite3.connect('/content/BTCUSD_data_SMALL.db')

# Read the data from the 'trades' table, sorted by DATETIME
df = pd.read_sql_query("SELECT * FROM btc_usd_data ORDER BY '<DATE>' ASC", conn)

# Iterate through the rows, simulating a live tick stream
for index, row in df.iterrows():
    print(f"DATE: {row['<DATE>']}, TIME: {row['<TIME>']}, BID: {row['<BID>']}, ASK: {row['<ASK>']}, LAST: {row['<LAST>']}")
    time.sleep(1)  # Adjust the sleep time to control the printing speed

# Close the database connection
conn.close()
# Out:
# DATE: 2024.11.14, TIME: 22:40:00.121, BID: nan, ASK: nan, LAST: 87968.63
# DATE: 2024.11.14, TIME: 22:40:00.121, BID: 87944.63, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:00.221, BID: nan, ASK: nan, LAST: 87965.52
# DATE: 2024.11.14, TIME: 22:40:00.222, BID: 87943.39, ASK: 87987.64, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:00.321, BID: nan, ASK: nan, LAST: 87964.71
# DATE: 2024.11.14, TIME: 22:40:00.322, BID: 87941.77, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:00.423, BID: nan, ASK: nan, LAST: 87964.0
# DATE: 2024.11.14, TIME: 22:40:00.423, BID: nan, ASK: 87986.22, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:00.724, BID: nan, ASK: nan, LAST: 87966.94
# DATE: 2024.11.14, TIME: 22:40:00.724, BID: nan, ASK: 87992.11, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:00.825, BID: nan, ASK: nan, LAST: 87945.11
# DATE: 2024.11.14, TIME: 22:40:00.825, BID: 87898.11, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:00.925, BID: nan, ASK: nan, LAST: 87931.27
# DATE: 2024.11.14, TIME: 22:40:00.925, BID: nan, ASK: 87964.43, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.021, BID: nan, ASK: nan, LAST: 87931.87
# DATE: 2024.11.14, TIME: 22:40:01.021, BID: nan, ASK: 87965.62, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.123, BID: nan, ASK: nan, LAST: 87941.99
# DATE: 2024.11.14, TIME: 22:40:01.124, BID: 87918.36, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.224, BID: nan, ASK: nan, LAST: 87943.78
# DATE: 2024.11.14, TIME: 22:40:01.225, BID: nan, ASK: 87969.2, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.323, BID: nan, ASK: nan, LAST: 87946.18
# DATE: 2024.11.14, TIME: 22:40:01.323, BID: nan, ASK: 87974.0, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.421, BID: nan, ASK: nan, LAST: 87954.56
# DATE: 2024.11.14, TIME: 22:40:01.421, BID: 87930.99, ASK: 87978.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.520, BID: nan, ASK: nan, LAST: 87956.06
# DATE: 2024.11.14, TIME: 22:40:01.521, BID: nan, ASK: 87981.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.622, BID: nan, ASK: nan, LAST: 87959.87
# DATE: 2024.11.14, TIME: 22:40:01.623, BID: 87938.11, ASK: 87981.62, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.724, BID: nan, ASK: nan, LAST: 87959.98
# DATE: 2024.11.14, TIME: 22:40:01.725, BID: 87937.61, ASK: 87982.34, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.827, BID: nan, ASK: nan, LAST: 87957.12
# DATE: 2024.11.14, TIME: 22:40:01.827, BID: 87931.89, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:01.924, BID: nan, ASK: nan, LAST: 87959.88
# DATE: 2024.11.14, TIME: 22:40:01.924, BID: nan, ASK: 87987.87, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.121, BID: nan, ASK: nan, LAST: 87957.79
# DATE: 2024.11.14, TIME: 22:40:02.121, BID: 87933.95, ASK: 87981.62, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.220, BID: nan, ASK: nan, LAST: 87957.5
# DATE: 2024.11.14, TIME: 22:40:02.220, BID: 87933.37, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.322, BID: nan, ASK: nan, LAST: 87955.5
# DATE: 2024.11.14, TIME: 22:40:02.322, BID: 87929.37, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.421, BID: nan, ASK: nan, LAST: 87949.07
# DATE: 2024.11.14, TIME: 22:40:02.421, BID: 87925.75, ASK: 87972.38, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.521, BID: nan, ASK: nan, LAST: 87948.94
# DATE: 2024.11.14, TIME: 22:40:02.521, BID: 87925.5, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.624, BID: nan, ASK: nan, LAST: 87946.18
# DATE: 2024.11.14, TIME: 22:40:02.624, BID: 87924.67, ASK: 87967.68, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.721, BID: nan, ASK: nan, LAST: 87946.58
# DATE: 2024.11.14, TIME: 22:40:02.721, BID: 87924.19, ASK: 87968.96, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.821, BID: nan, ASK: nan, LAST: 87943.98
# DATE: 2024.11.14, TIME: 22:40:02.821, BID: 87919.0, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:02.922, BID: nan, ASK: nan, LAST: 87943.34
# DATE: 2024.11.14, TIME: 22:40:02.922, BID: nan, ASK: 87967.67, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.025, BID: nan, ASK: nan, LAST: 87944.18
# DATE: 2024.11.14, TIME: 22:40:03.025, BID: nan, ASK: 87969.35, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.129, BID: nan, ASK: nan, LAST: 87947.85
# DATE: 2024.11.14, TIME: 22:40:03.129, BID: 87926.34, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.226, BID: nan, ASK: nan, LAST: 87947.0
# DATE: 2024.11.14, TIME: 22:40:03.226, BID: 87924.65, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.325, BID: nan, ASK: nan, LAST: 87946.78
# DATE: 2024.11.14, TIME: 22:40:03.325, BID: nan, ASK: 87968.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.521, BID: nan, ASK: nan, LAST: 87947.16
# DATE: 2024.11.14, TIME: 22:40:03.521, BID: 87925.4, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.622, BID: nan, ASK: nan, LAST: 87945.41
# DATE: 2024.11.14, TIME: 22:40:03.622, BID: 87923.9, ASK: 87966.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.729, BID: nan, ASK: nan, LAST: 87945.28
# DATE: 2024.11.14, TIME: 22:40:03.729, BID: 87923.65, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.824, BID: nan, ASK: nan, LAST: 87947.39
# DATE: 2024.11.14, TIME: 22:40:03.824, BID: nan, ASK: 87971.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:03.925, BID: nan, ASK: nan, LAST: 87949.62
# DATE: 2024.11.14, TIME: 22:40:03.925, BID: 87928.11, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.031, BID: nan, ASK: nan, LAST: 87953.71
# DATE: 2024.11.14, TIME: 22:40:05.031, BID: 87929.04, ASK: 87978.37, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.129, BID: nan, ASK: nan, LAST: 87955.46
# DATE: 2024.11.14, TIME: 22:40:05.129, BID: nan, ASK: 87981.87, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.328, BID: nan, ASK: nan, LAST: 87961.12
# DATE: 2024.11.14, TIME: 22:40:05.328, BID: 87939.36, ASK: 87982.87, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.427, BID: nan, ASK: nan, LAST: 87961.87
# DATE: 2024.11.14, TIME: 22:40:05.427, BID: nan, ASK: 87984.37, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.526, BID: nan, ASK: nan, LAST: 87962.87
# DATE: 2024.11.14, TIME: 22:40:05.526, BID: 87941.36, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.625, BID: nan, ASK: nan, LAST: 87962.62
# DATE: 2024.11.14, TIME: 22:40:05.625, BID: 87941.11, ASK: 87984.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.725, BID: nan, ASK: nan, LAST: 87956.09
# DATE: 2024.11.14, TIME: 22:40:05.725, BID: 87928.06, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.823, BID: nan, ASK: nan, LAST: 87954.63
# DATE: 2024.11.14, TIME: 22:40:05.823, BID: 87925.13, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:05.930, BID: nan, ASK: nan, LAST: 87948.09
# DATE: 2024.11.14, TIME: 22:40:05.930, BID: nan, ASK: 87971.05, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:06.029, BID: nan, ASK: nan, LAST: 87948.46
# DATE: 2024.11.14, TIME: 22:40:06.029, BID: nan, ASK: 87971.79, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:06.128, BID: nan, ASK: nan, LAST: 87949.42
# DATE: 2024.11.14, TIME: 22:40:06.128, BID: 87927.05, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:06.228, BID: nan, ASK: nan, LAST: 87948.97
# DATE: 2024.11.14, TIME: 22:40:06.228, BID: nan, ASK: 87970.89, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:06.429, BID: nan, ASK: nan, LAST: 87948.89
# DATE: 2024.11.14, TIME: 22:40:06.429, BID: 87926.88, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:06.524, BID: nan, ASK: nan, LAST: 87949.41
# DATE: 2024.11.14, TIME: 22:40:06.524, BID: 87926.63, ASK: 87972.19, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:06.625, BID: nan, ASK: nan, LAST: 87950.0
# DATE: 2024.11.14, TIME: 22:40:06.625, BID: nan, ASK: 87973.37, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:06.825, BID: nan, ASK: nan, LAST: 87951.74
# DATE: 2024.11.14, TIME: 22:40:06.825, BID: 87930.11, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:06.932, BID: nan, ASK: nan, LAST: 87950.87
# DATE: 2024.11.14, TIME: 22:40:06.932, BID: 87929.36, ASK: 87972.37, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:07.024, BID: nan, ASK: nan, LAST: 87950.74
# DATE: 2024.11.14, TIME: 22:40:07.024, BID: 87929.11, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:07.130, BID: nan, ASK: nan, LAST: 87950.87
# DATE: 2024.11.14, TIME: 22:40:07.130, BID: nan, ASK: 87972.62, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:07.228, BID: nan, ASK: nan, LAST: 87951.62
# DATE: 2024.11.14, TIME: 22:40:07.228, BID: 87930.11, ASK: 87973.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:07.330, BID: nan, ASK: nan, LAST: 87950.23
# DATE: 2024.11.14, TIME: 22:40:07.330, BID: 87927.34, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:07.531, BID: nan, ASK: nan, LAST: 87949.73
# DATE: 2024.11.14, TIME: 22:40:07.532, BID: nan, ASK: 87972.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:07.628, BID: nan, ASK: nan, LAST: 87950.62
# DATE: 2024.11.14, TIME: 22:40:07.628, BID: 87929.11, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:07.926, BID: nan, ASK: nan, LAST: 87958.12
# DATE: 2024.11.14, TIME: 22:40:07.926, BID: 87935.11, ASK: 87981.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:08.026, BID: nan, ASK: nan, LAST: 87958.87
# DATE: 2024.11.14, TIME: 22:40:08.026, BID: nan, ASK: 87982.62, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:08.230, BID: nan, ASK: nan, LAST: 87962.24
# DATE: 2024.11.14, TIME: 22:40:08.230, BID: 87939.61, ASK: 87984.87, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:08.327, BID: nan, ASK: nan, LAST: 87963.37
# DATE: 2024.11.14, TIME: 22:40:08.327, BID: nan, ASK: 87987.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:08.428, BID: nan, ASK: nan, LAST: 87964.12
# DATE: 2024.11.14, TIME: 22:40:08.428, BID: 87941.11, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:08.534, BID: nan, ASK: nan, LAST: 87963.37
# DATE: 2024.11.14, TIME: 22:40:08.534, BID: nan, ASK: 87985.62, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:08.726, BID: nan, ASK: nan, LAST: 87972.09
# DATE: 2024.11.14, TIME: 22:40:08.726, BID: 87950.36, ASK: 87993.82, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:08.829, BID: nan, ASK: nan, LAST: 87973.57
# DATE: 2024.11.14, TIME: 22:40:08.829, BID: nan, ASK: 87996.78, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:08.929, BID: nan, ASK: nan, LAST: 87977.44
# DATE: 2024.11.14, TIME: 22:40:08.929, BID: 87955.93, ASK: 87998.94, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:09.030, BID: nan, ASK: nan, LAST: 87978.66
# DATE: 2024.11.14, TIME: 22:40:09.030, BID: nan, ASK: 88001.39, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:09.130, BID: nan, ASK: nan, LAST: 87983.08
# DATE: 2024.11.14, TIME: 22:40:09.130, BID: nan, ASK: 88010.22, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:09.227, BID: nan, ASK: nan, LAST: 87977.49
# DATE: 2024.11.14, TIME: 22:40:09.227, BID: 87944.75, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:09.430, BID: nan, ASK: nan, LAST: 87970.31
# DATE: 2024.11.14, TIME: 22:40:09.431, BID: nan, ASK: 87995.86, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:09.533, BID: nan, ASK: nan, LAST: 87974.35
# DATE: 2024.11.14, TIME: 22:40:09.533, BID: 87952.83, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:09.631, BID: nan, ASK: nan, LAST: 87974.34
# DATE: 2024.11.14, TIME: 22:40:09.631, BID: nan, ASK: 87995.84, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:09.832, BID: nan, ASK: nan, LAST: 87976.11
# DATE: 2024.11.14, TIME: 22:40:09.832, BID: 87954.36, ASK: 87997.85, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:10.130, BID: nan, ASK: nan, LAST: 87976.35
# DATE: 2024.11.14, TIME: 22:40:10.130, BID: 87954.84, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:10.231, BID: nan, ASK: nan, LAST: 87976.36
# DATE: 2024.11.14, TIME: 22:40:10.231, BID: nan, ASK: 87997.88, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:10.330, BID: nan, ASK: nan, LAST: 87979.97
# DATE: 2024.11.14, TIME: 22:40:10.330, BID: 87954.87, ASK: 88005.06, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:10.428, BID: nan, ASK: nan, LAST: 87981.19
# DATE: 2024.11.14, TIME: 22:40:10.428, BID: nan, ASK: 88007.51, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:10.530, BID: nan, ASK: nan, LAST: 87975.88
# DATE: 2024.11.14, TIME: 22:40:10.530, BID: 87944.25, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:10.628, BID: nan, ASK: nan, LAST: 87967.26
# DATE: 2024.11.14, TIME: 22:40:10.628, BID: nan, ASK: 87990.26, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:10.734, BID: nan, ASK: nan, LAST: 87968.76
# DATE: 2024.11.14, TIME: 22:40:10.734, BID: 87947.25, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:10.828, BID: nan, ASK: nan, LAST: 87974.91
# DATE: 2024.11.14, TIME: 22:40:10.828, BID: nan, ASK: 88002.56, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:11.029, BID: nan, ASK: nan, LAST: 87978.04
# DATE: 2024.11.14, TIME: 22:40:11.029, BID: 87953.51, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:11.128, BID: nan, ASK: nan, LAST: 87975.02
# DATE: 2024.11.14, TIME: 22:40:11.128, BID: nan, ASK: 87996.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:11.633, BID: nan, ASK: nan, LAST: 87978.94
# DATE: 2024.11.14, TIME: 22:40:11.633, BID: 87957.43, ASK: 88000.44, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:11.733, BID: nan, ASK: nan, LAST: 87979.8
# DATE: 2024.11.14, TIME: 22:40:11.733, BID: nan, ASK: 88002.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:11.828, BID: nan, ASK: nan, LAST: 87980.66
# DATE: 2024.11.14, TIME: 22:40:11.828, BID: 87959.15, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:12.032, BID: nan, ASK: nan, LAST: 87978.74
# DATE: 2024.11.14, TIME: 22:40:12.032, BID: 87954.92, ASK: 88002.56, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:12.332, BID: nan, ASK: nan, LAST: 87977.9
# DATE: 2024.11.14, TIME: 22:40:12.332, BID: 87956.39, ASK: 87999.4, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:12.434, BID: nan, ASK: nan, LAST: 87979.28
# DATE: 2024.11.14, TIME: 22:40:12.434, BID: nan, ASK: 88002.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:12.629, BID: nan, ASK: nan, LAST: 87980.66
# DATE: 2024.11.14, TIME: 22:40:12.630, BID: 87959.15, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:12.934, BID: nan, ASK: nan, LAST: 87982.06
# DATE: 2024.11.14, TIME: 22:40:12.934, BID: 87960.55, ASK: 88003.56, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:13.034, BID: nan, ASK: nan, LAST: 87981.36
# DATE: 2024.11.14, TIME: 22:40:13.035, BID: 87959.15, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:13.232, BID: nan, ASK: nan, LAST: 87980.66
# DATE: 2024.11.14, TIME: 22:40:13.232, BID: nan, ASK: 88002.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:13.432, BID: nan, ASK: nan, LAST: 87985.31
# DATE: 2024.11.14, TIME: 22:40:13.433, BID: 87963.2, ASK: 88007.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:13.529, BID: nan, ASK: nan, LAST: 87987.91
# DATE: 2024.11.14, TIME: 22:40:13.529, BID: nan, ASK: 88012.61, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:13.631, BID: nan, ASK: nan, LAST: 87990.01
# DATE: 2024.11.14, TIME: 22:40:13.632, BID: 87967.4, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:13.736, BID: nan, ASK: nan, LAST: 87988.71
# DATE: 2024.11.14, TIME: 22:40:13.736, BID: 87967.2, ASK: 88010.21, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:13.932, BID: nan, ASK: nan, LAST: 87988.81
# DATE: 2024.11.14, TIME: 22:40:13.932, BID: nan, ASK: 88010.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:14.234, BID: nan, ASK: nan, LAST: 87988.91
# DATE: 2024.11.14, TIME: 22:40:14.235, BID: 87967.4, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:14.535, BID: nan, ASK: nan, LAST: 88000.41
# DATE: 2024.11.14, TIME: 22:40:14.535, BID: 87978.9, ASK: 88021.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:14.631, BID: nan, ASK: nan, LAST: 87996.74
# DATE: 2024.11.14, TIME: 22:40:14.631, BID: 87971.57, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:14.831, BID: nan, ASK: nan, LAST: 87995.87
# DATE: 2024.11.14, TIME: 22:40:14.831, BID: nan, ASK: 88020.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:14.935, BID: nan, ASK: nan, LAST: 87998.66
# DATE: 2024.11.14, TIME: 22:40:14.935, BID: 87977.15, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:15.331, BID: nan, ASK: nan, LAST: 87998.74
# DATE: 2024.11.14, TIME: 22:40:15.331, BID: 87977.23, ASK: 88020.24, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:15.432, BID: nan, ASK: nan, LAST: 88006.6
# DATE: 2024.11.14, TIME: 22:40:15.432, BID: nan, ASK: 88035.96, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:15.534, BID: nan, ASK: nan, LAST: 88011.88
# DATE: 2024.11.14, TIME: 22:40:15.535, BID: nan, ASK: 88046.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:15.632, BID: nan, ASK: nan, LAST: 88024.37
# DATE: 2024.11.14, TIME: 22:40:15.632, BID: 87994.74, ASK: 88054.0, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:15.832, BID: nan, ASK: nan, LAST: 88021.12
# DATE: 2024.11.14, TIME: 22:40:15.832, BID: 87988.24, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:15.934, BID: nan, ASK: nan, LAST: 88017.87
# DATE: 2024.11.14, TIME: 22:40:15.934, BID: nan, ASK: 88047.49, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.035, BID: nan, ASK: nan, LAST: 88021.24
# DATE: 2024.11.14, TIME: 22:40:16.035, BID: nan, ASK: 88054.24, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.133, BID: 88011.48, ASK: 88068.24, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.140, BID: nan, ASK: nan, LAST: 88039.86
# DATE: 2024.11.14, TIME: 22:40:16.241, BID: nan, ASK: nan, LAST: 88040.49
# DATE: 2024.11.14, TIME: 22:40:16.241, BID: nan, ASK: 88069.49, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.337, BID: nan, ASK: nan, LAST: 88045.86
# DATE: 2024.11.14, TIME: 22:40:16.338, BID: 88022.23, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.435, BID: nan, ASK: nan, LAST: 88044.49
# DATE: 2024.11.14, TIME: 22:40:16.436, BID: 88019.23, ASK: 88069.74, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.635, BID: nan, ASK: nan, LAST: 88044.75
# DATE: 2024.11.14, TIME: 22:40:16.635, BID: nan, ASK: 88070.26, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.736, BID: nan, ASK: nan, LAST: 88049.5
# DATE: 2024.11.14, TIME: 22:40:16.736, BID: 88027.25, ASK: 88071.74, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.838, BID: nan, ASK: nan, LAST: 88043.06
# DATE: 2024.11.14, TIME: 22:40:16.838, BID: 88014.38, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:16.938, BID: nan, ASK: nan, LAST: 88043.82
# DATE: 2024.11.14, TIME: 22:40:16.938, BID: nan, ASK: 88073.26, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.035, BID: nan, ASK: nan, LAST: 88043.94
# DATE: 2024.11.14, TIME: 22:40:17.035, BID: nan, ASK: 88073.5, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.139, BID: nan, ASK: nan, LAST: 88052.25
# DATE: 2024.11.14, TIME: 22:40:17.139, BID: 88030.74, ASK: 88073.75, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.234, BID: nan, ASK: nan, LAST: 88045.55
# DATE: 2024.11.14, TIME: 22:40:17.234, BID: 88017.02, ASK: 88074.08, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.335, BID: nan, ASK: nan, LAST: 88046.05
# DATE: 2024.11.14, TIME: 22:40:17.335, BID: nan, ASK: 88075.08, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.441, BID: nan, ASK: nan, LAST: 88046.1
# DATE: 2024.11.14, TIME: 22:40:17.441, BID: 88017.12, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.637, BID: nan, ASK: nan, LAST: 88031.89
# DATE: 2024.11.14, TIME: 22:40:17.637, BID: 88003.64, ASK: 88060.13, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.736, BID: nan, ASK: nan, LAST: 88024.19
# DATE: 2024.11.14, TIME: 22:40:17.736, BID: 87988.24, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.841, BID: nan, ASK: nan, LAST: 88024.26
# DATE: 2024.11.14, TIME: 22:40:17.841, BID: nan, ASK: 88060.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:17.938, BID: nan, ASK: nan, LAST: 88026.12
# DATE: 2024.11.14, TIME: 22:40:17.938, BID: nan, ASK: 88063.99, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:18.038, BID: nan, ASK: nan, LAST: 88041.55
# DATE: 2024.11.14, TIME: 22:40:18.038, BID: 88019.11, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:18.137, BID: nan, ASK: nan, LAST: 88045.3
# DATE: 2024.11.14, TIME: 22:40:18.137, BID: nan, ASK: 88071.48, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:18.236, BID: nan, ASK: nan, LAST: 88028.58
# DATE: 2024.11.14, TIME: 22:40:18.236, BID: 87985.67, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:18.339, BID: nan, ASK: nan, LAST: 88028.07
# DATE: 2024.11.14, TIME: 22:40:18.339, BID: 87984.66, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:18.641, BID: nan, ASK: nan, LAST: 88030.57
# DATE: 2024.11.14, TIME: 22:40:18.641, BID: 88006.56, ASK: 88054.58, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:18.745, BID: nan, ASK: nan, LAST: 88024.12
# DATE: 2024.11.14, TIME: 22:40:18.745, BID: 87993.66, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:18.841, BID: nan, ASK: nan, LAST: 88024.87
# DATE: 2024.11.14, TIME: 22:40:18.841, BID: nan, ASK: 88056.07, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:18.938, BID: nan, ASK: nan, LAST: 88025.01
# DATE: 2024.11.14, TIME: 22:40:18.938, BID: 87992.2, ASK: 88057.82, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.040, BID: nan, ASK: nan, LAST: 88029.26
# DATE: 2024.11.14, TIME: 22:40:19.041, BID: nan, ASK: 88066.32, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.137, BID: nan, ASK: nan, LAST: 88043.82
# DATE: 2024.11.14, TIME: 22:40:19.137, BID: 88021.31, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.242, BID: nan, ASK: nan, LAST: 88042.82
# DATE: 2024.11.14, TIME: 22:40:19.242, BID: 88019.31, ASK: 88066.33, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.338, BID: nan, ASK: nan, LAST: 88046.19
# DATE: 2024.11.14, TIME: 22:40:19.338, BID: nan, ASK: 88073.07, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.439, BID: nan, ASK: nan, LAST: 88053.82
# DATE: 2024.11.14, TIME: 22:40:19.439, BID: 88032.31, ASK: 88075.33, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.535, BID: nan, ASK: nan, LAST: 88055.57
# DATE: 2024.11.14, TIME: 22:40:19.535, BID: nan, ASK: 88078.83, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.636, BID: nan, ASK: nan, LAST: 88052.98
# DATE: 2024.11.14, TIME: 22:40:19.636, BID: 88027.12, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.740, BID: nan, ASK: nan, LAST: 88044.17
# DATE: 2024.11.14, TIME: 22:40:19.740, BID: 88022.64, ASK: 88065.69, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:19.843, BID: nan, ASK: nan, LAST: 88043.17
# DATE: 2024.11.14, TIME: 22:40:19.843, BID: 88020.64, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.045, BID: nan, ASK: nan, LAST: 88057.57
# DATE: 2024.11.14, TIME: 22:40:20.045, BID: 88035.81, ASK: 88079.32, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.138, BID: nan, ASK: nan, LAST: 88052.32
# DATE: 2024.11.14, TIME: 22:40:20.138, BID: 88025.31, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.240, BID: nan, ASK: nan, LAST: 88058.99
# DATE: 2024.11.14, TIME: 22:40:20.240, BID: nan, ASK: 88092.66, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.443, BID: nan, ASK: nan, LAST: 88067.36
# DATE: 2024.11.14, TIME: 22:40:20.443, BID: 88042.06, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.537, BID: nan, ASK: nan, LAST: 88056.55
# DATE: 2024.11.14, TIME: 22:40:20.537, BID: 88031.17, ASK: 88081.92, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.642, BID: nan, ASK: nan, LAST: 88058.25
# DATE: 2024.11.14, TIME: 22:40:20.643, BID: nan, ASK: 88085.32, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.737, BID: nan, ASK: nan, LAST: 88062.94
# DATE: 2024.11.14, TIME: 22:40:20.738, BID: 88040.56, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.840, BID: nan, ASK: nan, LAST: 88062.07
# DATE: 2024.11.14, TIME: 22:40:20.840, BID: nan, ASK: 88083.57, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:20.939, BID: nan, ASK: nan, LAST: 88065.94
# DATE: 2024.11.14, TIME: 22:40:20.940, BID: 88040.06, ASK: 88091.82, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.044, BID: nan, ASK: nan, LAST: 88063.85
# DATE: 2024.11.14, TIME: 22:40:21.044, BID: nan, ASK: 88087.64, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.144, BID: nan, ASK: nan, LAST: 88065.01
# DATE: 2024.11.14, TIME: 22:40:21.144, BID: 88042.38, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.239, BID: nan, ASK: nan, LAST: 88068.26
# DATE: 2024.11.14, TIME: 22:40:21.239, BID: nan, ASK: 88094.14, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.339, BID: nan, ASK: nan, LAST: 88069.39
# DATE: 2024.11.14, TIME: 22:40:21.339, BID: nan, ASK: 88096.4, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.440, BID: nan, ASK: nan, LAST: 88063.98
# DATE: 2024.11.14, TIME: 22:40:21.440, BID: 88029.56, ASK: 88098.4, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.643, BID: nan, ASK: nan, LAST: 88059.25
# DATE: 2024.11.14, TIME: 22:40:21.644, BID: 88037.74, ASK: 88080.75, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.740, BID: nan, ASK: nan, LAST: 88058.62
# DATE: 2024.11.14, TIME: 22:40:21.740, BID: 88036.49, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.845, BID: nan, ASK: nan, LAST: 88057.05
# DATE: 2024.11.14, TIME: 22:40:21.845, BID: 88033.35, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:21.943, BID: nan, ASK: nan, LAST: 88054.86
# DATE: 2024.11.14, TIME: 22:40:21.943, BID: nan, ASK: 88076.36, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:22.041, BID: nan, ASK: nan, LAST: 88060.34
# DATE: 2024.11.14, TIME: 22:40:22.041, BID: nan, ASK: 88087.33, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:22.143, BID: nan, ASK: nan, LAST: 88072.38
# DATE: 2024.11.14, TIME: 22:40:22.143, BID: 88046.61, ASK: 88098.14, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:22.243, BID: nan, ASK: nan, LAST: 88079.58
# DATE: 2024.11.14, TIME: 22:40:22.243, BID: nan, ASK: 88112.55, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:22.441, BID: nan, ASK: nan, LAST: 88084.39
# DATE: 2024.11.14, TIME: 22:40:22.441, BID: 88062.88, ASK: 88105.89, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:22.546, BID: nan, ASK: nan, LAST: 88083.26
# DATE: 2024.11.14, TIME: 22:40:22.546, BID: 88060.63, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:22.741, BID: nan, ASK: nan, LAST: 88087.76
# DATE: 2024.11.14, TIME: 22:40:22.742, BID: nan, ASK: 88114.89, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:22.837, BID: nan, ASK: nan, LAST: 88092.89
# DATE: 2024.11.14, TIME: 22:40:22.837, BID: 88070.88, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:22.941, BID: nan, ASK: nan, LAST: 88086.79
# DATE: 2024.11.14, TIME: 22:40:22.942, BID: 88057.19, ASK: 88116.39, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:23.046, BID: nan, ASK: nan, LAST: 88086.01
# DATE: 2024.11.14, TIME: 22:40:23.046, BID: 88055.62, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:23.140, BID: nan, ASK: nan, LAST: 88081.93
# DATE: 2024.11.14, TIME: 22:40:23.140, BID: nan, ASK: 88108.24, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:23.339, BID: nan, ASK: nan, LAST: 88085.61
# DATE: 2024.11.14, TIME: 22:40:23.339, BID: 88062.97, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:23.447, BID: nan, ASK: nan, LAST: 88084.48
# DATE: 2024.11.14, TIME: 22:40:23.447, BID: nan, ASK: 88105.98, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:23.541, BID: nan, ASK: nan, LAST: 88088.41
# DATE: 2024.11.14, TIME: 22:40:23.541, BID: 88057.19, ASK: 88119.63, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:23.743, BID: nan, ASK: nan, LAST: 88086.16
# DATE: 2024.11.14, TIME: 22:40:23.743, BID: nan, ASK: 88115.13, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:23.846, BID: nan, ASK: nan, LAST: 88092.63
# DATE: 2024.11.14, TIME: 22:40:23.846, BID: 88070.12, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:23.948, BID: nan, ASK: nan, LAST: 88092.38
# DATE: 2024.11.14, TIME: 22:40:23.948, BID: 88069.62, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.046, BID: nan, ASK: nan, LAST: 88091.0
# DATE: 2024.11.14, TIME: 22:40:24.046, BID: 88069.37, ASK: 88112.63, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.148, BID: nan, ASK: nan, LAST: 88094.63
# DATE: 2024.11.14, TIME: 22:40:24.148, BID: 88069.12, ASK: 88120.13, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.243, BID: nan, ASK: nan, LAST: 88093.54
# DATE: 2024.11.14, TIME: 22:40:24.243, BID: 88066.95, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.342, BID: nan, ASK: nan, LAST: 88081.1
# DATE: 2024.11.14, TIME: 22:40:24.342, BID: 88057.39, ASK: 88104.81, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.443, BID: nan, ASK: nan, LAST: 88084.04
# DATE: 2024.11.14, TIME: 22:40:24.443, BID: nan, ASK: 88110.68, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.544, BID: nan, ASK: nan, LAST: 88085.85
# DATE: 2024.11.14, TIME: 22:40:24.544, BID: nan, ASK: 88114.31, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.645, BID: nan, ASK: nan, LAST: 88092.56
# DATE: 2024.11.14, TIME: 22:40:24.645, BID: 88070.8, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.741, BID: nan, ASK: nan, LAST: 88091.69
# DATE: 2024.11.14, TIME: 22:40:24.741, BID: 88069.56, ASK: 88113.82, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.843, BID: nan, ASK: nan, LAST: 88090.05
# DATE: 2024.11.14, TIME: 22:40:24.843, BID: 88066.27, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:24.943, BID: nan, ASK: nan, LAST: 88085.53
# DATE: 2024.11.14, TIME: 22:40:24.943, BID: 88064.02, ASK: 88107.03, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:25.046, BID: nan, ASK: nan, LAST: 88087.56
# DATE: 2024.11.14, TIME: 22:40:25.046, BID: nan, ASK: 88111.1, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:25.150, BID: nan, ASK: nan, LAST: 88089.6
# DATE: 2024.11.14, TIME: 22:40:25.150, BID: 88068.09, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:25.843, BID: nan, ASK: nan, LAST: 88074.27
# DATE: 2024.11.14, TIME: 22:40:25.843, BID: 88039.43, ASK: 88109.11, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:25.942, BID: nan, ASK: nan, LAST: 88073.1
# DATE: 2024.11.14, TIME: 22:40:25.942, BID: 88037.08, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:26.042, BID: nan, ASK: nan, LAST: 88071.96
# DATE: 2024.11.14, TIME: 22:40:26.042, BID: 88034.81, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:26.142, BID: nan, ASK: nan, LAST: 88053.84
# DATE: 2024.11.14, TIME: 22:40:26.142, BID: 88029.1, ASK: 88078.57, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:26.444, BID: nan, ASK: nan, LAST: 88055.16
# DATE: 2024.11.14, TIME: 22:40:26.444, BID: 88032.65, ASK: 88077.66, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:26.544, BID: nan, ASK: nan, LAST: 88054.28
# DATE: 2024.11.14, TIME: 22:40:26.544, BID: 88030.9, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:26.642, BID: nan, ASK: nan, LAST: 88057.03
# DATE: 2024.11.14, TIME: 22:40:26.642, BID: nan, ASK: 88083.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:26.845, BID: nan, ASK: nan, LAST: 88055.16
# DATE: 2024.11.14, TIME: 22:40:26.846, BID: 88033.65, ASK: 88076.66, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:26.947, BID: nan, ASK: nan, LAST: 88054.3
# DATE: 2024.11.14, TIME: 22:40:26.947, BID: 88031.92, ASK: 88076.68, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:27.144, BID: nan, ASK: nan, LAST: 88059.55
# DATE: 2024.11.14, TIME: 22:40:27.144, BID: 88035.92, ASK: 88083.18, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:27.248, BID: nan, ASK: nan, LAST: 88061.88
# DATE: 2024.11.14, TIME: 22:40:27.248, BID: nan, ASK: 88087.83, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:27.345, BID: nan, ASK: nan, LAST: 88062.93
# DATE: 2024.11.14, TIME: 22:40:27.345, BID: nan, ASK: 88089.93, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:27.443, BID: nan, ASK: nan, LAST: 88066.8
# DATE: 2024.11.14, TIME: 22:40:27.443, BID: 88043.67, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:27.543, BID: nan, ASK: nan, LAST: 88062.36
# DATE: 2024.11.14, TIME: 22:40:27.543, BID: 88039.53, ASK: 88085.18, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:27.746, BID: nan, ASK: nan, LAST: 88063.43
# DATE: 2024.11.14, TIME: 22:40:27.746, BID: 88041.67, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:27.848, BID: nan, ASK: nan, LAST: 88062.8
# DATE: 2024.11.14, TIME: 22:40:27.848, BID: 88040.92, ASK: 88084.68, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:27.946, BID: nan, ASK: nan, LAST: 88062.18
# DATE: 2024.11.14, TIME: 22:40:27.946, BID: 88039.67, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:28.046, BID: nan, ASK: nan, LAST: 88060.68
# DATE: 2024.11.14, TIME: 22:40:28.046, BID: 88038.67, ASK: 88082.68, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:28.148, BID: nan, ASK: nan, LAST: 88060.55
# DATE: 2024.11.14, TIME: 22:40:28.148, BID: 88038.42, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:28.250, BID: nan, ASK: nan, LAST: 88058.11
# DATE: 2024.11.14, TIME: 22:40:28.250, BID: 88033.53, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:28.345, BID: nan, ASK: nan, LAST: 88053.18
# DATE: 2024.11.14, TIME: 22:40:28.345, BID: 88029.81, ASK: 88076.54, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:28.542, BID: nan, ASK: nan, LAST: 88056.3
# DATE: 2024.11.14, TIME: 22:40:28.542, BID: nan, ASK: 88082.79, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:28.647, BID: nan, ASK: nan, LAST: 88059.02
# DATE: 2024.11.14, TIME: 22:40:28.647, BID: 88035.24, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:28.747, BID: nan, ASK: nan, LAST: 88058.9
# DATE: 2024.11.14, TIME: 22:40:28.747, BID: 88034.98, ASK: 88082.81, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:28.845, BID: nan, ASK: nan, LAST: 88059.64
# DATE: 2024.11.14, TIME: 22:40:28.845, BID: 88036.47, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.047, BID: nan, ASK: nan, LAST: 88063.94
# DATE: 2024.11.14, TIME: 22:40:29.047, BID: nan, ASK: 88091.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.250, BID: nan, ASK: nan, LAST: 88058.08
# DATE: 2024.11.14, TIME: 22:40:29.251, BID: 88036.57, ASK: 88079.58, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.344, BID: nan, ASK: nan, LAST: 88057.82
# DATE: 2024.11.14, TIME: 22:40:29.344, BID: 88036.06, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.449, BID: nan, ASK: nan, LAST: 88061.74
# DATE: 2024.11.14, TIME: 22:40:29.449, BID: nan, ASK: 88087.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.549, BID: nan, ASK: nan, LAST: 88064.49
# DATE: 2024.11.14, TIME: 22:40:29.549, BID: nan, ASK: 88092.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.650, BID: nan, ASK: nan, LAST: 88070.41
# DATE: 2024.11.14, TIME: 22:40:29.650, BID: 88047.9, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.756, BID: nan, ASK: nan, LAST: 88062.3
# DATE: 2024.11.14, TIME: 22:40:29.756, BID: 88040.79, ASK: 88083.8, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.856, BID: nan, ASK: nan, LAST: 88062.05
# DATE: 2024.11.14, TIME: 22:40:29.856, BID: 88040.29, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:29.947, BID: nan, ASK: nan, LAST: 88061.42
# DATE: 2024.11.14, TIME: 22:40:29.947, BID: 88039.04, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:30.055, BID: nan, ASK: nan, LAST: 88060.05
# DATE: 2024.11.14, TIME: 22:40:30.055, BID: 88038.54, ASK: 88081.55, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:30.151, BID: nan, ASK: nan, LAST: 88058.91
# DATE: 2024.11.14, TIME: 22:40:30.152, BID: 88036.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:30.250, BID: nan, ASK: nan, LAST: 88063.59
# DATE: 2024.11.14, TIME: 22:40:30.251, BID: nan, ASK: 88090.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:30.454, BID: nan, ASK: nan, LAST: 88071.16
# DATE: 2024.11.14, TIME: 22:40:30.454, BID: 88047.4, ASK: 88094.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:30.553, BID: nan, ASK: nan, LAST: 88067.88
# DATE: 2024.11.14, TIME: 22:40:30.553, BID: 88040.84, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:30.646, BID: nan, ASK: nan, LAST: 88067.0
# DATE: 2024.11.14, TIME: 22:40:30.647, BID: nan, ASK: 88093.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:30.751, BID: nan, ASK: nan, LAST: 88071.13
# DATE: 2024.11.14, TIME: 22:40:30.751, BID: nan, ASK: 88101.42, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:30.854, BID: nan, ASK: nan, LAST: 88084.16
# DATE: 2024.11.14, TIME: 22:40:30.855, BID: 88061.4, ASK: 88106.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:31.148, BID: nan, ASK: nan, LAST: 88086.41
# DATE: 2024.11.14, TIME: 22:40:31.148, BID: nan, ASK: 88111.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:31.249, BID: nan, ASK: nan, LAST: 88088.66
# DATE: 2024.11.14, TIME: 22:40:31.249, BID: 88065.4, ASK: 88111.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:31.450, BID: nan, ASK: nan, LAST: 88089.16
# DATE: 2024.11.14, TIME: 22:40:31.450, BID: nan, ASK: 88112.92, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:31.648, BID: nan, ASK: nan, LAST: 88087.31
# DATE: 2024.11.14, TIME: 22:40:31.648, BID: 88059.95, ASK: 88114.66, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:31.749, BID: nan, ASK: nan, LAST: 88084.27
# DATE: 2024.11.14, TIME: 22:40:31.749, BID: 88055.38, ASK: 88113.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:31.871, BID: nan, ASK: nan, LAST: 88089.53
# DATE: 2024.11.14, TIME: 22:40:31.871, BID: 88067.9, ASK: 88111.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:31.947, BID: nan, ASK: nan, LAST: 88090.28
# DATE: 2024.11.14, TIME: 22:40:31.948, BID: 88067.65, ASK: 88112.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:32.152, BID: nan, ASK: nan, LAST: 88092.91
# DATE: 2024.11.14, TIME: 22:40:32.152, BID: 88071.4, ASK: 88114.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:32.252, BID: nan, ASK: nan, LAST: 88092.16
# DATE: 2024.11.14, TIME: 22:40:32.252, BID: 88069.9, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:32.347, BID: nan, ASK: nan, LAST: 88092.16
# DATE: 2024.11.14, TIME: 22:40:32.347, BID: 88069.15, ASK: 88115.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:32.452, BID: nan, ASK: nan, LAST: 88090.89
# DATE: 2024.11.14, TIME: 22:40:32.452, BID: 88066.61, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:32.552, BID: nan, ASK: nan, LAST: 88092.01
# DATE: 2024.11.14, TIME: 22:40:32.552, BID: nan, ASK: 88117.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:32.651, BID: nan, ASK: nan, LAST: 88097.92
# DATE: 2024.11.14, TIME: 22:40:32.651, BID: 88072.92, ASK: 88122.92, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:32.854, BID: nan, ASK: nan, LAST: 88096.57
# DATE: 2024.11.14, TIME: 22:40:32.854, BID: 88070.21, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:32.953, BID: nan, ASK: nan, LAST: 88095.31
# DATE: 2024.11.14, TIME: 22:40:32.953, BID: nan, ASK: 88120.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.050, BID: nan, ASK: nan, LAST: 88099.39
# DATE: 2024.11.14, TIME: 22:40:33.050, BID: nan, ASK: 88128.57, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.151, BID: nan, ASK: nan, LAST: 88106.29
# DATE: 2024.11.14, TIME: 22:40:33.151, BID: 88083.15, ASK: 88129.42, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.252, BID: nan, ASK: nan, LAST: 88104.2
# DATE: 2024.11.14, TIME: 22:40:33.252, BID: 88078.97, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.353, BID: nan, ASK: nan, LAST: 88103.04
# DATE: 2024.11.14, TIME: 22:40:33.353, BID: 88076.66, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.451, BID: nan, ASK: nan, LAST: 88098.18
# DATE: 2024.11.14, TIME: 22:40:33.451, BID: nan, ASK: 88119.69, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.551, BID: nan, ASK: nan, LAST: 88097.18
# DATE: 2024.11.14, TIME: 22:40:33.551, BID: 88074.66, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.652, BID: nan, ASK: nan, LAST: 88096.93
# DATE: 2024.11.14, TIME: 22:40:33.652, BID: 88074.16, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.753, BID: nan, ASK: nan, LAST: 88094.92
# DATE: 2024.11.14, TIME: 22:40:33.753, BID: 88072.66, ASK: 88117.17, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:33.950, BID: nan, ASK: nan, LAST: 88094.8
# DATE: 2024.11.14, TIME: 22:40:33.950, BID: nan, ASK: 88116.94, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:34.051, BID: nan, ASK: nan, LAST: 88095.44
# DATE: 2024.11.14, TIME: 22:40:34.051, BID: 88073.93, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:34.754, BID: nan, ASK: nan, LAST: 88098.3
# DATE: 2024.11.14, TIME: 22:40:34.754, BID: nan, ASK: 88122.66, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:34.954, BID: nan, ASK: nan, LAST: 88103.55
# DATE: 2024.11.14, TIME: 22:40:34.954, BID: nan, ASK: 88133.17, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:35.056, BID: nan, ASK: nan, LAST: 88107.3
# DATE: 2024.11.14, TIME: 22:40:35.056, BID: 88081.43, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:35.253, BID: nan, ASK: nan, LAST: 88105.53
# DATE: 2024.11.14, TIME: 22:40:35.253, BID: 88083.4, ASK: 88127.66, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:35.453, BID: nan, ASK: nan, LAST: 88097.93
# DATE: 2024.11.14, TIME: 22:40:35.453, BID: 88076.41, ASK: 88119.44, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:35.553, BID: nan, ASK: nan, LAST: 88096.8
# DATE: 2024.11.14, TIME: 22:40:35.553, BID: 88074.16, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:35.655, BID: nan, ASK: nan, LAST: 88095.68
# DATE: 2024.11.14, TIME: 22:40:35.656, BID: 88071.91, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:35.752, BID: nan, ASK: nan, LAST: 88093.43
# DATE: 2024.11.14, TIME: 22:40:35.753, BID: nan, ASK: 88114.94, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:35.855, BID: nan, ASK: nan, LAST: 88092.31
# DATE: 2024.11.14, TIME: 22:40:35.855, BID: 88069.68, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:35.957, BID: nan, ASK: nan, LAST: 88090.3
# DATE: 2024.11.14, TIME: 22:40:35.957, BID: 88067.32, ASK: 88113.28, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:36.154, BID: nan, ASK: nan, LAST: 88101.99
# DATE: 2024.11.14, TIME: 22:40:36.154, BID: 88079.53, ASK: 88124.44, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:36.256, BID: nan, ASK: nan, LAST: 88115.07
# DATE: 2024.11.14, TIME: 22:40:36.256, BID: nan, ASK: 88150.6, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:36.356, BID: nan, ASK: nan, LAST: 88127.89
# DATE: 2024.11.14, TIME: 22:40:36.357, BID: nan, ASK: 88176.25, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:36.457, BID: nan, ASK: nan, LAST: 88147.61
# DATE: 2024.11.14, TIME: 22:40:36.457, BID: 88118.97, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:36.552, BID: nan, ASK: nan, LAST: 88141.61
# DATE: 2024.11.14, TIME: 22:40:36.552, BID: 88106.97, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:36.651, BID: nan, ASK: nan, LAST: 88129.95
# DATE: 2024.11.14, TIME: 22:40:36.651, BID: 88096.25, ASK: 88163.64, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:36.852, BID: nan, ASK: nan, LAST: 88124.77
# DATE: 2024.11.14, TIME: 22:40:36.852, BID: nan, ASK: 88153.28, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:36.956, BID: nan, ASK: nan, LAST: 88134.46
# DATE: 2024.11.14, TIME: 22:40:36.956, BID: 88112.59, ASK: 88156.33, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:37.058, BID: nan, ASK: nan, LAST: 88134.48
# DATE: 2024.11.14, TIME: 22:40:37.058, BID: nan, ASK: 88156.37, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:37.153, BID: nan, ASK: nan, LAST: 88133.36
# DATE: 2024.11.14, TIME: 22:40:37.153, BID: 88110.34, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:37.255, BID: nan, ASK: nan, LAST: 88125.19
# DATE: 2024.11.14, TIME: 22:40:37.255, BID: 88090.98, ASK: 88159.39, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:37.453, BID: nan, ASK: nan, LAST: 88124.83
# DATE: 2024.11.14, TIME: 22:40:37.453, BID: nan, ASK: 88158.67, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:37.554, BID: nan, ASK: nan, LAST: 88130.71
# DATE: 2024.11.14, TIME: 22:40:37.554, BID: 88102.74, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:37.754, BID: nan, ASK: nan, LAST: 88129.98
# DATE: 2024.11.14, TIME: 22:40:37.755, BID: 88102.23, ASK: 88157.72, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:37.953, BID: nan, ASK: nan, LAST: 88129.06
# DATE: 2024.11.14, TIME: 22:40:37.953, BID: 88100.4, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.057, BID: nan, ASK: nan, LAST: 88124.56
# DATE: 2024.11.14, TIME: 22:40:38.057, BID: nan, ASK: 88148.72, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.158, BID: nan, ASK: nan, LAST: 88121.72
# DATE: 2024.11.14, TIME: 22:40:38.158, BID: 88093.97, ASK: 88149.47, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.259, BID: nan, ASK: nan, LAST: 88124.74
# DATE: 2024.11.14, TIME: 22:40:38.259, BID: nan, ASK: 88155.5, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.356, BID: nan, ASK: nan, LAST: 88136.67
# DATE: 2024.11.14, TIME: 22:40:38.356, BID: 88115.16, ASK: 88158.17, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.458, BID: nan, ASK: nan, LAST: 88135.67
# DATE: 2024.11.14, TIME: 22:40:38.458, BID: 88113.16, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.558, BID: nan, ASK: nan, LAST: 88131.88
# DATE: 2024.11.14, TIME: 22:40:38.558, BID: 88105.59, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.660, BID: nan, ASK: nan, LAST: 88128.25
# DATE: 2024.11.14, TIME: 22:40:38.660, BID: 88103.34, ASK: 88153.16, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.755, BID: nan, ASK: nan, LAST: 88128.26
# DATE: 2024.11.14, TIME: 22:40:38.755, BID: nan, ASK: 88153.17, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.859, BID: nan, ASK: nan, LAST: 88133.09
# DATE: 2024.11.14, TIME: 22:40:38.859, BID: 88111.58, ASK: 88154.59, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:38.960, BID: nan, ASK: nan, LAST: 88130.61
# DATE: 2024.11.14, TIME: 22:40:38.960, BID: 88106.62, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:39.059, BID: nan, ASK: nan, LAST: 88128.6
# DATE: 2024.11.14, TIME: 22:40:39.059, BID: 88102.61, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:39.156, BID: nan, ASK: nan, LAST: 88124.87
# DATE: 2024.11.14, TIME: 22:40:39.156, BID: nan, ASK: 88147.13, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:39.354, BID: nan, ASK: nan, LAST: 88125.63
# DATE: 2024.11.14, TIME: 22:40:39.354, BID: 88104.12, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:39.455, BID: nan, ASK: nan, LAST: 88124.85
# DATE: 2024.11.14, TIME: 22:40:39.455, BID: 88102.61, ASK: 88147.08, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:39.656, BID: nan, ASK: nan, LAST: 88125.58
# DATE: 2024.11.14, TIME: 22:40:39.656, BID: 88104.07, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:39.755, BID: nan, ASK: nan, LAST: 88125.55
# DATE: 2024.11.14, TIME: 22:40:39.755, BID: 88104.04, ASK: 88147.05, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:39.957, BID: nan, ASK: nan, LAST: 88115.05
# DATE: 2024.11.14, TIME: 22:40:39.957, BID: 88093.54, ASK: 88136.55, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:40.060, BID: nan, ASK: nan, LAST: 88124.04
# DATE: 2024.11.14, TIME: 22:40:40.060, BID: 88092.32, ASK: 88155.76, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:40.356, BID: nan, ASK: nan, LAST: 88133.88
# DATE: 2024.11.14, TIME: 22:40:40.356, BID: 88112.37, ASK: 88155.38, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:40.859, BID: nan, ASK: nan, LAST: 88105.61
# DATE: 2024.11.14, TIME: 22:40:40.859, BID: 88074.96, ASK: 88136.25, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:41.058, BID: nan, ASK: nan, LAST: 88113.29
# DATE: 2024.11.14, TIME: 22:40:41.058, BID: 88090.33, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:41.160, BID: nan, ASK: nan, LAST: 88100.48
# DATE: 2024.11.14, TIME: 22:40:41.160, BID: 88077.76, ASK: 88123.2, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:41.263, BID: nan, ASK: nan, LAST: 88099.36
# DATE: 2024.11.14, TIME: 22:40:41.263, BID: 88075.51, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:41.359, BID: nan, ASK: nan, LAST: 88095.89
# DATE: 2024.11.14, TIME: 22:40:41.359, BID: 88073.26, ASK: 88118.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:41.658, BID: nan, ASK: nan, LAST: 88092.05
# DATE: 2024.11.14, TIME: 22:40:41.659, BID: 88067.65, ASK: 88116.44, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:41.761, BID: nan, ASK: nan, LAST: 88090.93
# DATE: 2024.11.14, TIME: 22:40:41.761, BID: 88065.41, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:41.861, BID: nan, ASK: nan, LAST: 88078.12
# DATE: 2024.11.14, TIME: 22:40:41.861, BID: 88053.04, ASK: 88103.2, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:41.961, BID: nan, ASK: nan, LAST: 88074.94
# DATE: 2024.11.14, TIME: 22:40:41.961, BID: 88046.67, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.065, BID: nan, ASK: nan, LAST: 88077.78
# DATE: 2024.11.14, TIME: 22:40:42.066, BID: 88045.45, ASK: 88110.11, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.159, BID: nan, ASK: nan, LAST: 88079.48
# DATE: 2024.11.14, TIME: 22:40:42.159, BID: nan, ASK: 88113.5, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.257, BID: nan, ASK: nan, LAST: 88089.38
# DATE: 2024.11.14, TIME: 22:40:42.257, BID: 88065.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.361, BID: nan, ASK: nan, LAST: 88086.15
# DATE: 2024.11.14, TIME: 22:40:42.361, BID: 88064.03, ASK: 88108.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.462, BID: nan, ASK: nan, LAST: 88082.54
# DATE: 2024.11.14, TIME: 22:40:42.462, BID: 88056.8, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.558, BID: nan, ASK: nan, LAST: 88082.21
# DATE: 2024.11.14, TIME: 22:40:42.558, BID: 88056.15, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.661, BID: nan, ASK: nan, LAST: 88079.23
# DATE: 2024.11.14, TIME: 22:40:42.661, BID: 88053.94, ASK: 88104.51, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.764, BID: nan, ASK: nan, LAST: 88071.45
# DATE: 2024.11.14, TIME: 22:40:42.764, BID: 88032.42, ASK: 88110.48, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:42.958, BID: nan, ASK: nan, LAST: 88060.42
# DATE: 2024.11.14, TIME: 22:40:42.958, BID: nan, ASK: 88088.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:43.064, BID: nan, ASK: nan, LAST: 88065.51
# DATE: 2024.11.14, TIME: 22:40:43.064, BID: 88031.55, ASK: 88099.47, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:43.163, BID: nan, ASK: nan, LAST: 88066.58
# DATE: 2024.11.14, TIME: 22:40:43.163, BID: nan, ASK: 88101.6, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:43.262, BID: nan, ASK: nan, LAST: 88075.03
# DATE: 2024.11.14, TIME: 22:40:43.262, BID: 88048.45, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:43.364, BID: nan, ASK: nan, LAST: 88069.84
# DATE: 2024.11.14, TIME: 22:40:43.364, BID: 88048.33, ASK: 88091.34, LAST: nan
# DATE: 2024.11.14, TIME: 22:40:43.560, BID: nan, ASK: nan, LAST: 88061.45
# DATE: 2024.11.14, TIME: 22:40:43.560, BID: 88031.55, ASK: nan, LAST: nan
# ...
# DATE: 2024.11.14, TIME: 22:42:11.937, BID: nan, ASK: nan, LAST: 87992.53
# DATE: 2024.11.14, TIME: 22:42:11.937, BID: 87970.51, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.042, BID: nan, ASK: nan, LAST: 87992.44
# DATE: 2024.11.14, TIME: 22:42:12.042, BID: 87969.51, ASK: 88015.37, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.141, BID: nan, ASK: nan, LAST: 87995.95
# DATE: 2024.11.14, TIME: 22:42:12.141, BID: nan, ASK: 88022.39, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.242, BID: nan, ASK: nan, LAST: 88000.89
# DATE: 2024.11.14, TIME: 22:42:12.242, BID: 87979.38, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.343, BID: nan, ASK: nan, LAST: 87992.07
# DATE: 2024.11.14, TIME: 22:42:12.343, BID: 87961.75, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.439, BID: nan, ASK: nan, LAST: 87984.38
# DATE: 2024.11.14, TIME: 22:42:12.440, BID: nan, ASK: 88007.01, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.543, BID: nan, ASK: nan, LAST: 87987.77
# DATE: 2024.11.14, TIME: 22:42:12.543, BID: 87966.26, ASK: 88009.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.643, BID: nan, ASK: nan, LAST: 87988.89
# DATE: 2024.11.14, TIME: 22:42:12.644, BID: nan, ASK: 88011.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.737, BID: nan, ASK: nan, LAST: 87990.02
# DATE: 2024.11.14, TIME: 22:42:12.738, BID: nan, ASK: 88013.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.839, BID: nan, ASK: nan, LAST: 87992.27
# DATE: 2024.11.14, TIME: 22:42:12.839, BID: 87970.76, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:12.941, BID: nan, ASK: nan, LAST: 87993.39
# DATE: 2024.11.14, TIME: 22:42:12.941, BID: nan, ASK: 88016.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:13.060, BID: nan, ASK: nan, LAST: 87994.52
# DATE: 2024.11.14, TIME: 22:42:13.060, BID: 87973.01, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:13.143, BID: nan, ASK: nan, LAST: 87989.02
# DATE: 2024.11.14, TIME: 22:42:13.143, BID: 87967.51, ASK: 88010.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:13.343, BID: nan, ASK: nan, LAST: 87987.64
# DATE: 2024.11.14, TIME: 22:42:13.343, BID: 87962.5, ASK: 88012.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:13.538, BID: nan, ASK: nan, LAST: 87985.01
# DATE: 2024.11.14, TIME: 22:42:13.538, BID: nan, ASK: 88007.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:13.643, BID: nan, ASK: nan, LAST: 87987.14
# DATE: 2024.11.14, TIME: 22:42:13.643, BID: 87964.51, ASK: 88009.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:13.840, BID: nan, ASK: nan, LAST: 87986.77
# DATE: 2024.11.14, TIME: 22:42:13.840, BID: 87961.51, ASK: 88012.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.042, BID: nan, ASK: nan, LAST: 87985.14
# DATE: 2024.11.14, TIME: 22:42:14.042, BID: nan, ASK: 88008.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.144, BID: nan, ASK: nan, LAST: 87988.39
# DATE: 2024.11.14, TIME: 22:42:14.144, BID: 87965.76, ASK: 88011.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.237, BID: nan, ASK: nan, LAST: 87987.89
# DATE: 2024.11.14, TIME: 22:42:14.238, BID: 87964.76, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.339, BID: nan, ASK: nan, LAST: 87985.43
# DATE: 2024.11.14, TIME: 22:42:14.339, BID: 87959.83, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.442, BID: nan, ASK: nan, LAST: 87983.93
# DATE: 2024.11.14, TIME: 22:42:14.443, BID: nan, ASK: 88008.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.538, BID: nan, ASK: nan, LAST: 87997.01
# DATE: 2024.11.14, TIME: 22:42:14.539, BID: 87973.09, ASK: 88020.92, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.644, BID: nan, ASK: nan, LAST: 87994.22
# DATE: 2024.11.14, TIME: 22:42:14.644, BID: 87967.51, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.741, BID: nan, ASK: nan, LAST: 87992.19
# DATE: 2024.11.14, TIME: 22:42:14.741, BID: nan, ASK: 88016.87, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.839, BID: nan, ASK: nan, LAST: 87992.27
# DATE: 2024.11.14, TIME: 22:42:14.839, BID: nan, ASK: 88017.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:14.940, BID: nan, ASK: nan, LAST: 87992.64
# DATE: 2024.11.14, TIME: 22:42:14.940, BID: 87968.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:15.039, BID: nan, ASK: nan, LAST: 87990.77
# DATE: 2024.11.14, TIME: 22:42:15.039, BID: nan, ASK: 88013.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:15.141, BID: nan, ASK: nan, LAST: 87991.89
# DATE: 2024.11.14, TIME: 22:42:15.141, BID: nan, ASK: 88015.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:15.241, BID: nan, ASK: nan, LAST: 87994.77
# DATE: 2024.11.14, TIME: 22:42:15.241, BID: 87972.51, ASK: 88017.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:15.442, BID: nan, ASK: nan, LAST: 87993.02
# DATE: 2024.11.14, TIME: 22:42:15.442, BID: 87968.01, ASK: 88018.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:15.541, BID: nan, ASK: nan, LAST: 87994.02
# DATE: 2024.11.14, TIME: 22:42:15.541, BID: nan, ASK: 88020.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:15.745, BID: nan, ASK: nan, LAST: 87995.14
# DATE: 2024.11.14, TIME: 22:42:15.745, BID: 87970.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:15.845, BID: nan, ASK: nan, LAST: 87995.02
# DATE: 2024.11.14, TIME: 22:42:15.845, BID: nan, ASK: 88019.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:16.059, BID: nan, ASK: nan, LAST: 87993.27
# DATE: 2024.11.14, TIME: 22:42:16.059, BID: 87966.76, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:16.143, BID: nan, ASK: nan, LAST: 87987.64
# DATE: 2024.11.14, TIME: 22:42:16.143, BID: 87965.51, ASK: 88009.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:16.246, BID: nan, ASK: nan, LAST: 87993.39
# DATE: 2024.11.14, TIME: 22:42:16.246, BID: nan, ASK: 88021.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:16.341, BID: nan, ASK: nan, LAST: 87996.27
# DATE: 2024.11.14, TIME: 22:42:16.341, BID: 87971.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:16.448, BID: nan, ASK: nan, LAST: 87996.02
# DATE: 2024.11.14, TIME: 22:42:16.448, BID: 87970.76, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:16.541, BID: nan, ASK: nan, LAST: 87992.27
# DATE: 2024.11.14, TIME: 22:42:16.541, BID: nan, ASK: 88013.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:16.741, BID: nan, ASK: nan, LAST: 87995.46
# DATE: 2024.11.14, TIME: 22:42:16.741, BID: 87968.51, ASK: 88022.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:16.944, BID: nan, ASK: nan, LAST: 87992.27
# DATE: 2024.11.14, TIME: 22:42:16.944, BID: 87970.76, ASK: 88013.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:17.053, BID: nan, ASK: nan, LAST: 87991.39
# DATE: 2024.11.14, TIME: 22:42:17.053, BID: 87969.01, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:17.241, BID: 87969.76, ASK: 88012.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:17.247, BID: nan, ASK: nan, LAST: 87991.27
# DATE: 2024.11.14, TIME: 22:42:17.340, BID: nan, ASK: nan, LAST: 87992.39
# DATE: 2024.11.14, TIME: 22:42:17.340, BID: nan, ASK: 88015.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:17.446, BID: nan, ASK: nan, LAST: 87992.77
# DATE: 2024.11.14, TIME: 22:42:17.446, BID: nan, ASK: 88015.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:17.544, BID: nan, ASK: nan, LAST: 87994.64
# DATE: 2024.11.14, TIME: 22:42:17.544, BID: 87972.76, ASK: 88016.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:17.642, BID: nan, ASK: nan, LAST: 88002.47
# DATE: 2024.11.14, TIME: 22:42:17.642, BID: nan, ASK: 88032.18, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:17.744, BID: nan, ASK: nan, LAST: 88002.47
# DATE: 2024.11.14, TIME: 22:42:17.744, BID: 87972.75, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:17.946, BID: nan, ASK: nan, LAST: 87993.52
# DATE: 2024.11.14, TIME: 22:42:17.946, BID: 87971.26, ASK: 88015.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:18.147, BID: nan, ASK: nan, LAST: 87993.27
# DATE: 2024.11.14, TIME: 22:42:18.147, BID: nan, ASK: 88015.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:18.242, BID: nan, ASK: nan, LAST: 87991.27
# DATE: 2024.11.14, TIME: 22:42:18.242, BID: 87967.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:18.444, BID: nan, ASK: nan, LAST: 87996.59
# DATE: 2024.11.14, TIME: 22:42:18.444, BID: 87968.26, ASK: 88024.91, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:18.746, BID: nan, ASK: nan, LAST: 88001.79
# DATE: 2024.11.14, TIME: 22:42:18.746, BID: 87972.51, ASK: 88031.06, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:18.944, BID: nan, ASK: nan, LAST: 88010.75
# DATE: 2024.11.14, TIME: 22:42:18.944, BID: 87985.6, ASK: 88035.89, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:19.052, BID: nan, ASK: nan, LAST: 88004.32
# DATE: 2024.11.14, TIME: 22:42:19.053, BID: 87972.75, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:19.149, BID: nan, ASK: nan, LAST: 87991.27
# DATE: 2024.11.14, TIME: 22:42:19.149, BID: 87969.76, ASK: 88012.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:19.243, BID: nan, ASK: nan, LAST: 87992.27
# DATE: 2024.11.14, TIME: 22:42:19.243, BID: nan, ASK: 88014.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:19.448, BID: nan, ASK: nan, LAST: 87992.52
# DATE: 2024.11.14, TIME: 22:42:19.448, BID: 87970.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:19.547, BID: nan, ASK: nan, LAST: 87990.27
# DATE: 2024.11.14, TIME: 22:42:19.547, BID: 87966.51, ASK: 88014.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:19.744, BID: nan, ASK: nan, LAST: 87986.89
# DATE: 2024.11.14, TIME: 22:42:19.744, BID: 87964.76, ASK: 88009.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:19.847, BID: nan, ASK: nan, LAST: 87998.22
# DATE: 2024.11.14, TIME: 22:42:19.847, BID: nan, ASK: 88031.68, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:19.947, BID: nan, ASK: nan, LAST: 87999.47
# DATE: 2024.11.14, TIME: 22:42:19.948, BID: 87967.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.056, BID: nan, ASK: nan, LAST: 87987.89
# DATE: 2024.11.14, TIME: 22:42:20.056, BID: 87965.51, ASK: 88010.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.143, BID: nan, ASK: nan, LAST: 87986.11
# DATE: 2024.11.14, TIME: 22:42:20.143, BID: 87961.95, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.244, BID: nan, ASK: nan, LAST: 87985.39
# DATE: 2024.11.14, TIME: 22:42:20.244, BID: 87960.51, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.346, BID: nan, ASK: nan, LAST: 87990.92
# DATE: 2024.11.14, TIME: 22:42:20.346, BID: nan, ASK: 88021.32, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.544, BID: nan, ASK: nan, LAST: 87992.79
# DATE: 2024.11.14, TIME: 22:42:20.544, BID: 87964.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.650, BID: nan, ASK: nan, LAST: 87985.77
# DATE: 2024.11.14, TIME: 22:42:20.650, BID: nan, ASK: 88007.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.749, BID: nan, ASK: nan, LAST: 87985.27
# DATE: 2024.11.14, TIME: 22:42:20.749, BID: 87963.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.846, BID: nan, ASK: nan, LAST: 87984.89
# DATE: 2024.11.14, TIME: 22:42:20.847, BID: 87962.51, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:20.947, BID: nan, ASK: nan, LAST: 87983.99
# DATE: 2024.11.14, TIME: 22:42:20.947, BID: 87961.21, ASK: 88006.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:21.052, BID: nan, ASK: nan, LAST: 87983.52
# DATE: 2024.11.14, TIME: 22:42:21.052, BID: 87960.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:21.146, BID: nan, ASK: nan, LAST: 87990.24
# DATE: 2024.11.14, TIME: 22:42:21.146, BID: nan, ASK: 88020.22, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:21.349, BID: nan, ASK: nan, LAST: 87991.59
# DATE: 2024.11.14, TIME: 22:42:21.350, BID: 87962.95, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:21.445, BID: nan, ASK: nan, LAST: 87982.64
# DATE: 2024.11.14, TIME: 22:42:21.445, BID: 87961.01, ASK: 88004.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:21.651, BID: nan, ASK: nan, LAST: 87990.82
# DATE: 2024.11.14, TIME: 22:42:21.651, BID: 87961.51, ASK: 88020.13, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:21.849, BID: nan, ASK: nan, LAST: 87990.07
# DATE: 2024.11.14, TIME: 22:42:21.850, BID: 87960.01, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:21.948, BID: nan, ASK: nan, LAST: 87980.99
# DATE: 2024.11.14, TIME: 22:42:21.948, BID: 87958.96, ASK: 88003.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.052, BID: nan, ASK: nan, LAST: 87979.89
# DATE: 2024.11.14, TIME: 22:42:22.052, BID: 87956.75, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.148, BID: nan, ASK: nan, LAST: 87976.13
# DATE: 2024.11.14, TIME: 22:42:22.148, BID: 87954.62, ASK: 87997.63, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.247, BID: nan, ASK: nan, LAST: 87975.18
# DATE: 2024.11.14, TIME: 22:42:22.247, BID: 87952.73, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.345, BID: nan, ASK: nan, LAST: 87966.63
# DATE: 2024.11.14, TIME: 22:42:22.345, BID: 87935.63, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.446, BID: nan, ASK: nan, LAST: 87965.18
# DATE: 2024.11.14, TIME: 22:42:22.446, BID: 87934.51, ASK: 87995.85, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.546, BID: nan, ASK: nan, LAST: 87966.32
# DATE: 2024.11.14, TIME: 22:42:22.546, BID: nan, ASK: 87998.12, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.655, BID: nan, ASK: nan, LAST: 87975.27
# DATE: 2024.11.14, TIME: 22:42:22.655, BID: nan, ASK: 88016.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.748, BID: nan, ASK: nan, LAST: 87997.01
# DATE: 2024.11.14, TIME: 22:42:22.748, BID: 87972.99, ASK: 88021.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:22.951, BID: nan, ASK: nan, LAST: 88001.77
# DATE: 2024.11.14, TIME: 22:42:22.951, BID: 87980.26, ASK: 88023.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.049, BID: nan, ASK: nan, LAST: 88002.89
# DATE: 2024.11.14, TIME: 22:42:23.049, BID: nan, ASK: 88025.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.149, BID: nan, ASK: nan, LAST: 88004.02
# DATE: 2024.11.14, TIME: 22:42:23.149, BID: nan, ASK: 88027.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.250, BID: nan, ASK: nan, LAST: 88007.39
# DATE: 2024.11.14, TIME: 22:42:23.250, BID: 87984.76, ASK: 88030.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.347, BID: nan, ASK: nan, LAST: 88004.14
# DATE: 2024.11.14, TIME: 22:42:23.347, BID: 87978.01, ASK: 88030.27, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.548, BID: nan, ASK: nan, LAST: 88009.02
# DATE: 2024.11.14, TIME: 22:42:23.549, BID: 87987.51, ASK: 88030.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.649, BID: nan, ASK: nan, LAST: 88009.14
# DATE: 2024.11.14, TIME: 22:42:23.649, BID: nan, ASK: 88030.77, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.747, BID: nan, ASK: nan, LAST: 88009.89
# DATE: 2024.11.14, TIME: 22:42:23.747, BID: nan, ASK: 88032.26, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.853, BID: nan, ASK: nan, LAST: 88008.18
# DATE: 2024.11.14, TIME: 22:42:23.853, BID: 87984.09, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:23.952, BID: nan, ASK: nan, LAST: 88010.75
# DATE: 2024.11.14, TIME: 22:42:23.952, BID: nan, ASK: 88037.41, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:24.150, BID: nan, ASK: nan, LAST: 88011.02
# DATE: 2024.11.14, TIME: 22:42:24.150, BID: 87989.51, ASK: 88032.52, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:24.252, BID: nan, ASK: nan, LAST: 88009.89
# DATE: 2024.11.14, TIME: 22:42:24.253, BID: 87987.26, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:24.351, BID: nan, ASK: nan, LAST: 88008.0
# DATE: 2024.11.14, TIME: 22:42:24.351, BID: 87983.47, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:24.449, BID: nan, ASK: nan, LAST: 88004.1
# DATE: 2024.11.14, TIME: 22:42:24.449, BID: 87981.47, ASK: 88026.73, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:24.546, BID: nan, ASK: nan, LAST: 88002.57
# DATE: 2024.11.14, TIME: 22:42:24.546, BID: 87978.4, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:24.655, BID: nan, ASK: nan, LAST: 88001.7
# DATE: 2024.11.14, TIME: 22:42:24.655, BID: 87976.66, ASK: nan, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:24.748, BID: nan, ASK: nan, LAST: 87998.17
# DATE: 2024.11.14, TIME: 22:42:24.748, BID: nan, ASK: 88019.67, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:24.951, BID: nan, ASK: nan, LAST: 87982.75
# DATE: 2024.11.14, TIME: 22:42:24.951, BID: 87961.24, ASK: 88004.25, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:25.249, BID: nan, ASK: nan, LAST: 87978.52
# DATE: 2024.11.14, TIME: 22:42:25.249, BID: 87957.01, ASK: 88000.02, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:25.550, BID: nan, ASK: nan, LAST: 87978.35
# DATE: 2024.11.14, TIME: 22:42:25.550, BID: 87956.84, ASK: 87999.85, LAST: nan
# DATE: 2024.11.14, TIME: 22:42:27.749, BID: nan, ASK: nan, LAST: 87977.97
# DATE: 2024.11.14, TIME: 22:42:27.749, BID: 87956.14, ASK: 87999.8, LAST: nan
